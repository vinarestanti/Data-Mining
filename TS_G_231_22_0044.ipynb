# %% [markdown]
# <a href="https://colab.research.google.com/github/vinarestanti/Data-Mining/blob/main/TS_G_231_22_0044.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from math import sqrt
from math import log
from math import exp
from scipy.stats import boxcox
from pandas import DataFrame
from pandas import Grouper
from pandas import Series
from pandas import concat
from pandas.plotting import lag_plot
from matplotlib import pyplot
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARIMAResults
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.gofplots import qqplot

# %%
series = read_csv('/content/AirPassengers.csv', header=0, index_col=0, parse_dates=True).squeeze()
print(series.head())
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# Name: #Passengers, dtype: int64

# %%
print(series.describe())
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: #Passengers, dtype: float64

# %%
# Visualisasi nilai pada plot garis, yang dapat memberikan banyak wawasan tentang masalah tersebut
series.plot()
pyplot.show()

# %%
# Konfirmasi asumsi dengan plot garis tahunan.
groups = series['1949':'1957'].groupby(Grouper(freq='A'))
years = DataFrame()
pyplot.figure()
i = 1
n_groups = len(groups)
for name, group in groups:
    pyplot.subplot(n_groups * 100 + 10 + i)
    pyplot.plot(group)
    i += 1
pyplot.show()

# %%
# Struktur Data
pyplot.figure(1)
pyplot.subplot(211)
series.hist()
pyplot.subplot(212)
series.plot(kind='kde')
pyplot.show()

# %%
# Analisis data bulanan berdasarkan tahun dan gambaran tentang penyebaran observasi untuk setiap tahun.
groups = series['1949':'1968'].groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.boxplot()
pyplot.show()

# %%
# Uraikan deret waktu untuk kejelasan lebih lanjut tentang komponennya - Level, Tren, Musim, dan Kebisingan.
result = seasonal_decompose(series, model='multiplicative')
result.plot()
pyplot.show()
